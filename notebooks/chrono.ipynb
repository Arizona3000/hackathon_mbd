# %%
import pandas as pd

# %%
df_retail = pd.read_csv('../data/retailer.csv')
programatic = pd.read_csv('../data/programmatic_publisher.csv')
map = pd.read_csv('../data/mapping_transac_publisher_tv.csv')
tv = pd.read_csv('../data/tv_publisher.csv')

# %%
unique_customer_retail = set(df_retail['customer_id'].to_list())
map = map[map['customer_id'].isin(unique_customer_retail)]

# %%
pro_map = map[map['dsp_id']!='unknown'].merge(programatic, on='dsp_id', how='left')
pro_map = pro_map[pro_map['customer_id']!='unknown']

# %%
tv_map = map[map['device_id']!='unknown'].merge(tv, on='device_id', how='left')
tv_map = tv_map[tv_map['customer_id']!='unknown']

# %%
df_retail = df_retail[df_retail['customer_id']!='unknown']

# %%
pro_map['source_data'] = 'programatic'
tv_map['source_data'] = 'tv'
df_retail['source_data'] = 'retail'

# %%
pro_map['timestamp_utc'] = pd.to_datetime(pro_map['timestamp_utc'])
df_retail['timestamp_utc'] = pd.to_datetime(df_retail['timestamp_utc'])
tv_map['timestamp_utc'] = pd.to_datetime(tv_map['timestamp_utc'])

# %%
pro_map = pro_map[pro_map['timestamp_utc']>'2024-02-29 00:00:00']
df_retail = df_retail[df_retail['timestamp_utc']>'2024-02-29 00:00:00']
tv_map = tv_map[tv_map['timestamp_utc']>'2024-02-29 00:00:00']

# %%
pro_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1811293 entries, 3 to 4264085
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   customer_id                object
#  1   timestamp_utc              datetime64[ns]
#  2   cost_milli_cent            float64
#  3   source_data                object
#  4   campaign_name_Contextual   int64
#  5   campaign_name_Retargeting  int64
#  6   device_type_PC             int64
#  7   device_type_Phone          int64
#  8   device_type_TV             int64
#  9   device_type_Unknown        int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(2)
# memory usage: 152.0+ MB

# %%
#pro_map = pd.get_dummies(pro_map, columns=['campaign_name'], dtype=int)
#pro_map = pd.get_dummies(pro_map, columns=['device_type'], dtype=int)
#pro_map.drop(columns=['device_id', 'dsp_id'], inplace=True)
pro_map.rename(columns={'cost_milli_cent':'cost_milli_cent_programmatic'}, inplace=True)

# %%
pro_map
# Out:
#                 customer_id       timestamp_utc  cost_milli_cent_programmatic  \
# 3        reutQ3jiBX9Li4Ggqi 2024-06-16 20:55:27                       601.930
# 4        reH7UgH29AreRh8wWy 2024-06-26 19:15:54                      1191.750
# 5        reH7UgH29AreRh8wWy 2024-05-31 18:38:54                       739.262
# 6        reH7UgH29AreRh8wWy 2024-06-05 22:50:03                       153.500
# 7        reHAnmLXgIZqJT0i64 2024-05-09 21:06:22                      5878.010
# ...                     ...                 ...                           ...
# 4264069  reekGgat3Kzr52qMUX 2024-03-13 07:54:30                       425.913
# 4264070  reekGgat3Kzr52qMUX 2024-03-31 18:16:15                       280.017
# 4264071  reekGgat3Kzr52qMUX 2024-04-20 00:55:23                       192.684
# 4264077  re41cv7tOaVBHcqCPM 2024-05-27 13:11:54                      2875.684
# 4264085  revepSSHYRYZEOOd3l 2024-03-09 19:14:01                       216.300
#
#          source_data  campaign_name_Contextual  campaign_name_Retargeting  \
# 3        programatic                         1                          0
# 4        programatic                         1                          0
# 5        programatic                         0                          1
# 6        programatic                         0                          1
# 7        programatic                         1                          0
# ...              ...                       ...                        ...
# 4264069  programatic                         0                          1
# 4264070  programatic                         0                          1
# 4264071  programatic                         0                          1
# 4264077  programatic                         0                          1
# 4264085  programatic                         0                          1
#
#          device_type_PC  device_type_Phone  device_type_TV  \
# 3                     0                  0               1
# 4                     0                  0               1
# 5                     0                  0               1
# 6                     1                  0               0
# 7                     0                  0               1
# ...                 ...                ...             ...
# 4264069               0                  0               1
# 4264070               0                  0               1
# 4264071               0                  0               1
# 4264077               1                  0               0
# 4264085               0                  0               1
#
#          device_type_Unknown
# 3                          0
# 4                          0
# 5                          0
# 6                          0
# 7                          0
# ...                      ...
# 4264069                    0
# 4264070                    0
# 4264071                    0
# 4264077                    0
# 4264085                    0
#
# [1811293 rows x 10 columns]

# %%
df_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6146286 entries, 1 to 9866045
# Data columns (total 7 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   customer_id    object
#  1   timestamp_utc  datetime64[ns]
#  2   event_name     object
#  3   brand          object
#  4   product_name   object
#  5   sales          float64
#  6   quantity       float64
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 375.1+ MB

# %%
tv_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341760 entries, 0 to 1570129
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   customer_id      341760 non-null  object
#  1   dsp_id           341760 non-null  object
#  2   device_id        341760 non-null  object
#  3   timestamp_utc    341760 non-null  datetime64[ns]
#  4   cost_milli_cent  341760 non-null  float64
#  5   source_data      341760 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 18.3+ MB

# %%
#tv_map.drop(columns=['device_id', 'dsp_id'], inplace=True)
tv_map.rename(columns={'cost_milli_cent':'cost_milli_cent_tv'}, inplace=True)

# %%
full_history = pd.concat([df_retail, pro_map, tv_map], ignore_index=True)

# %%
full_history.sort_values(by=['customer_id', 'timestamp_utc'], inplace=True)

# %%
len(full_history[full_history['event_name']=='Order']) + len(full_history[full_history['event_name']!='Order']) == len(full_history)
# Out:
# True

# %%
order_history = full_history[(full_history['event_name']!='Product Page View') & (full_history['event_name']!='Add to cart')]

# %%
order_history['cost_milli_cent_programmatic'].sum()/100000
# Out:
# 14074.67311117

# %%
order_history.tail(30)
# Out:
#                 customer_id       timestamp_utc event_name              brand  \
# 6853059  rezzxDmygQV4OoBFA8 2024-02-29 14:39:36        NaN                NaN
# 6853060  rezzxDmygQV4OoBFA8 2024-03-05 05:59:13        NaN                NaN
# 6853061  rezzxDmygQV4OoBFA8 2024-03-07 01:02:38        NaN                NaN
# 6853066  rezzxDmygQV4OoBFA8 2024-03-07 01:08:03        NaN                NaN
# 6853062  rezzxDmygQV4OoBFA8 2024-03-07 01:21:15        NaN                NaN
# 6853063  rezzxDmygQV4OoBFA8 2024-03-07 01:22:55        NaN                NaN
# 6853064  rezzxDmygQV4OoBFA8 2024-03-07 01:36:17        NaN                NaN
# 6853067  rezzxDmygQV4OoBFA8 2024-03-07 01:41:02        NaN                NaN
# 6853065  rezzxDmygQV4OoBFA8 2024-03-07 01:45:49        NaN                NaN
# 3275658  rezzxDmygQV4OoBFA8 2024-05-24 00:02:01      Order       Science Diet
# 8279436  rezzxE79sGAxCblaga 2024-04-30 04:20:04        NaN                NaN
# 8046770  rezzxOak8u3yiEW7xr 2024-06-26 22:59:15        NaN                NaN
# 5731011  rezzxeE2Jq41nZhu0V 2024-05-29 14:11:14      Order       Science Diet
# 6853060                       424.950  programatic                       0.0
# 6853061                       749.267  programatic                       0.0
# 6853066                       557.175  programatic                       0.0
# 6853062                       612.414  programatic                       0.0
# 6853063                       743.489  programatic                       0.0
# 6853064                       557.175  programatic                       0.0
# 6853067                       557.175  programatic                       0.0
# 6853065                       557.175  programatic                       0.0
# 3275658                           NaN          NaN                       NaN
# 8279436                           NaN       retail                       NaN
# 8046770                           NaN       retail                       NaN
# 5731011                           NaN          NaN                       NaN
# 5731012                           NaN          NaN                       NaN
# 6209852                      1961.659  programatic                       0.0
# 646492                            NaN          NaN                       NaN
# 646489                            NaN          NaN                       NaN
# 6580494                       339.680  programatic                       0.0
# 8241780                           NaN       retail                       NaN
# 7111150                       890.699  programatic                       1.0
# 7111151                       423.147  programatic                       1.0
# 7111152                       248.440  programatic                       1.0
# 3257862                           NaN          NaN                       NaN
# 7368170                       146.610  programatic                       1.0
# 2203901                           NaN          NaN                       NaN
# 2203902                           NaN          NaN                       NaN
# 8062821                           NaN       retail                       NaN
# 8062822                           NaN       retail                       NaN
# 4142213                           NaN          NaN                       NaN
# 4142210                           NaN          NaN                       NaN
#
#          campaign_name_Retargeting  device_type_PC  device_type_Phone  \
# 6853059                        1.0             1.0                0.0
# 6853060                        1.0             1.0                0.0
# 6853061                        1.0             1.0                0.0
# 6853066                        1.0             0.0                1.0
# 6853062                        1.0             1.0                0.0
# 6853063                        1.0             1.0                0.0
# 6853064                        1.0             0.0                1.0
# 6853067                        1.0             0.0                1.0
# 6853065                        1.0             0.0                1.0
# 3275658                        NaN             NaN                NaN
# 8279436                        NaN             NaN                NaN
# 8046770                        NaN             NaN                NaN
# 5731011                        NaN             NaN                NaN
# 5731012                        NaN             NaN                NaN
# 6209852                        1.0             1.0                0.0
# 646492                         NaN             NaN                NaN
# 646489                         NaN             NaN                NaN
# 6580494                        1.0             1.0                0.0
# 8241780                        NaN             NaN                NaN
# 7111150                        0.0             0.0                0.0
# 7111151                        0.0             0.0                1.0
# 7111152                        0.0             0.0                1.0
# 3257862                        NaN             NaN                NaN
# 7368170                        0.0             0.0                1.0
# 2203901                        NaN             NaN                NaN
# 2203902                        NaN             NaN                NaN
# 8062821                        NaN             NaN                NaN
# 8062822                        NaN             NaN                NaN
# 4142213                        NaN             NaN                NaN
# 4142210                        NaN             NaN                NaN
#
#          device_type_TV  device_type_Unknown  cost_milli_cent_tv
# 6853059             0.0                  0.0                 NaN
# 6853060             0.0                  0.0                 NaN
# 6853061             0.0                  0.0                 NaN
# 6853066             0.0                  0.0                 NaN
# 6853062             0.0                  0.0                 NaN
# 6853063             0.0                  0.0                 NaN
# 6853064             0.0                  0.0                 NaN
# 6853067             0.0                  0.0                 NaN
# 6853065             0.0                  0.0                 NaN
# 3275658             NaN                  NaN                 NaN
# 8279436             NaN                  NaN             2325.51
# 8046770             NaN                  NaN             2325.51
# 5731011             NaN                  NaN                 NaN
# 5731012             NaN                  NaN                 NaN
# 6209852             0.0                  0.0                 NaN
# 646492              NaN                  NaN                 NaN
# 646489              NaN                  NaN                 NaN
# 6580494             0.0                  0.0                 NaN
# 8241780             NaN                  NaN             2325.51
# 7111150             1.0                  0.0                 NaN
# 7111151             0.0                  0.0                 NaN
# 7111152             0.0                  0.0                 NaN
# 3257862             NaN                  NaN                 NaN
# 7368170             0.0                  0.0                 NaN
# 2203901             NaN                  NaN                 NaN
# 2203902             NaN                  NaN                 NaN
# 8062821             NaN                  NaN             2325.51
# 8062822             NaN                  NaN             2325.51
# 4142213             NaN                  NaN                 NaN
# 4142210             NaN                  NaN                 NaN

# %%
# Sort data chronologically per customer
order_history = order_history.sort_values(by=['customer_id', 'timestamp_utc'])

# Columns to aggregate
ad_columns = [
    'cost_milli_cent_programmatic', 'campaign_name_Contextual', 'campaign_name_Retargeting',
    'device_type_PC', 'device_type_Phone', 'device_type_TV', 'device_type_Unknown', 'cost_milli_cent_tv'
]

# Identify ad type
ad_type_column = 'source_data'  # Used to determine if it's programmatic or TV
order_indicator = 'retail'  # Orders are identified with 'retail'

# Initialize tracking
order_data = []
current_sums = {col: 0 for col in ad_columns}  # Track sums before order
count_tv = 0
count_programmatic = 0
# Iterate through rows
for _, row in order_history.iterrows():
    if row['source_data'] == order_indicator:  # If it's an order
        # Store aggregated values
        order_data.append({
            'customer_id': row['customer_id'],
            'timestamp_utc': row['timestamp_utc'],
            'event_name' : row['event_name'],
            'brand' : row['brand'],
            'product_name' : row['product_name'],
            'sales' : row['sales'],
            'quantity': row['quantity'],
            **current_sums,  # Add all aggregated columns
            'count_tv_ads': count_tv,
            'count_programmatic_ads': count_programmatic
        })

        # Reset tracking after storing order data
        current_sums = {col: 0 for col in ad_columns}
        count_tv = 0
        count_programmatic = 0

    else:  # If it's an ad exposure
        for col in ad_columns:
            if pd.notna(row[col]):  # Ensure it's not NaN
                current_sums[col] += row[col]

        # Count ad types
        if row[ad_type_column] == 'programatic':
            count_programmatic += 1
        elif row[ad_type_column] == 'tv':
            count_tv += 1

# Create DataFrame with orders and their pre-order ad exposure
df_orders = pd.DataFrame(order_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:5587, in NDFrame.__setattr__(self, name, value)
#    5586 try:
# -> 5587     object.__getattribute__(self, name)
#    5588     return object.__setattr__(self, name, value)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/series.py:638, in Series.name(self)
#     592 """
#     593 Return the name of the Series.
#     594
#    (...)
#     636 'Even Numbers'
#     637 """
# --> 638 return self._name
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute '_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [52], line 20
#      18 count_programmatic = 0
#      19 # Iterate through rows
# ---> 20 for _, row in order_history.iterrows():
#      21     if row['source_data'] == order_indicator:  # If it's an order
#      22         # Store aggregated values
#      23         order_data.append({
#      24             'customer_id': row['customer_id'],
#      25             'timestamp_utc': row['timestamp_utc'],
#    (...)
#      33             'count_programmatic_ads': count_programmatic
#      34         })
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/frame.py:1324, in DataFrame.iterrows(self)
#    1322 klass = self._constructor_sliced
#    1323 for k, v in zip(self.index, self.values):
# -> 1324     s = klass(v, index=columns, name=k)
#    1325     yield k, s
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/series.py:460, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     457             data = SingleArrayManager.from_array(data, index)
#     459 NDFrame.__init__(self, data)
# --> 460 self.name = name
#     461 self._set_axis(0, index, fastpath=True)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:5587, in NDFrame.__setattr__(self, name, value)
#    5582 # first try regular attribute access via __getattribute__, so that
#    5583 # e.g. ``obj.x`` and ``obj.x = 4`` will always reference/modify
#    5584 # the same attribute.
#    5586 try:
# -> 5587     object.__getattribute__(self, name)
#    5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#
# KeyboardInterrupt:
